# %% [markdown]
# # My Jupyter Notebook

# %% [markdown]
# **Opeyemi Adeniran**
# Machine learning Engineer

# %% [markdown]
# *data science as become one the most needed skills in today's industry and this is majorly because of the influx of data generated everyday via social network and other platforms. More so, My passion towards solving problems using technology has been the main driving force towards learning data science skills*

# %% [markdown]
# ### The code below adds two numbers

# %%
num1 = 5
num2 = 65

# Add two numbers
sum = num1 + num2

# Display the sum
print('The sum of {0} and {1} is {2}'.format(num1, num2, sum))
# Out:
# The sum of 5 and 65 is 70

# %% [markdown]
# Hope you enjoyed python beginners class? Advanced class is now available, 50 % discount for the first 10 people that registered! ~~$50~~
#
# **Two people already registered,** *8 more people to close the deal*
#
# Registered members are listed below
#
# Name  | Email  | Phone number |
# ------| -------| -------------|
# Opeyemi | ope@gmail.co | 081657890
# Taiwo   | taiwo@gmail.com.ng | 09012345
